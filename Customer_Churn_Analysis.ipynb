# %% [markdown]
# # Problem Statement

# %% [markdown]
# Customer churn is when a company’s customers stop doing business with that company. Customer retention can be achieved with good customer service and products. But the most effective way for a company to prevent attrition of customers is to truly know them. The dataset consists of customer data from IBM Sample Data Sets which has volumes of data collected about customers that can be used to build churn prediction models.

# %% [markdown]
# The task is to train a machine learning model with the aim of building and comparing several customer churn prediction models.

# %% [markdown]
# # Importing Dataset

# %%
#Importing Libraries
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
# Importing Training Dataset
df=pd.read_csv(r'C:\Users\HP-15\Data Trained Projects\Telecom_customer_churn.csv')
#Visualizing first 5 rows of dataset
df
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 0     7590-VHVEG  Female              0     Yes         No       1
# 1     5575-GNVDE    Male              0      No         No      34
# 2     3668-QPYBK    Male              0      No         No       2
# 3     7795-CFOCW    Male              0      No         No      45
# 4     9237-HQITU  Female              0      No         No       2
# 5     9305-CDSKC  Female              0      No         No       8
# 6     1452-KIOVK    Male              0      No        Yes      22
# 7     6713-OKOMC  Female              0      No         No      10
# 8     7892-POOKP  Female              0     Yes         No      28
# 9     6388-TABGU    Male              0      No        Yes      62
# 10    9763-GRSKD    Male              0     Yes        Yes      13
# 11    7469-LKBCI    Male              0      No         No      16
# 12    8091-TTVAX    Male              0     Yes         No      58
# 13    0280-XJGEX    Male              0      No         No      49
# 14    5129-JLPIS    Male              0      No         No      25
# 15    3655-SNQYZ  Female              0     Yes        Yes      69
# 16    8191-XWSZG  Female              0      No         No      52
# 17    9959-WOFKT    Male              0      No        Yes      71
# 18    4190-MFLUW  Female              0     Yes        Yes      10
# 19    4183-MYFRB  Female              0      No         No      21
# 20    8779-QRDMV    Male              1      No         No       1
# 21    1680-VDCWW    Male              0     Yes         No      12
# 22    1066-JKSGK    Male              0      No         No       1
# 23    3638-WEABW  Female              0     Yes         No      58
# 24    6322-HRPFA    Male              0     Yes        Yes      49
# 25    6865-JZNKO  Female              0      No         No      30
# 26    6467-CHFZW    Male              0     Yes        Yes      47
# 27    8665-UTDHZ    Male              0     Yes        Yes       1
# 28    5248-YGIJN    Male              0     Yes         No      72
# 29    8773-HHUOZ  Female              0      No        Yes      17
# ...          ...     ...            ...     ...        ...     ...
# 7013  1685-BQULA  Female              0      No         No      40
# 7014  9053-EJUNL    Male              0      No         No      41
# 7015  0666-UXTJO    Male              1     Yes         No      34
# 7016  1471-GIQKQ  Female              0      No         No       1
# 7017  4807-IZYOZ  Female              0      No         No      51
# 7018  1122-JWTJW    Male              0     Yes        Yes       1
# 7019  9710-NJERN  Female              0      No         No      39
# 7020  9837-FWLCH    Male              0     Yes        Yes      12
# 7021  1699-HPSBG    Male              0      No         No      12
# 7022  7203-OYKCT    Male              0      No         No      72
# 7023  1035-IPQPU  Female              1     Yes         No      63
# 7024  7398-LXGYX    Male              0     Yes         No      44
# 7025  2823-LKABH  Female              0      No         No      18
# 7026  8775-CEBBJ  Female              0      No         No       9
# 7027  0550-DCXLH    Male              0      No         No      13
# 7028  9281-CEDRU  Female              0     Yes         No      68
# 7029  2235-DWLJU  Female              1      No         No       6
# 7030  0871-OPBXW  Female              0      No         No       2
# 7031  3605-JISKB    Male              1     Yes         No      55
# 7032  6894-LFHLY    Male              1      No         No       1
# 7033  9767-FFLEM    Male              0      No         No      38
# 7034  0639-TSIQW  Female              0      No         No      67
# 7035  8456-QDAVC    Male              0      No         No      19
# 7036  7750-EYXWZ  Female              0      No         No      12
# 7037  2569-WGERO  Female              0      No         No      72
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService       OnlineSecurity  ...  \
# 0              No  No phone service             DSL                   No  ...
# 1             Yes                No             DSL                  Yes  ...
# 2             Yes                No             DSL                  Yes  ...
# 3              No  No phone service             DSL                  Yes  ...
# 4             Yes                No     Fiber optic                   No  ...
# 5             Yes               Yes     Fiber optic                   No  ...
# 6             Yes               Yes     Fiber optic                   No  ...
# 7              No  No phone service             DSL                  Yes  ...
# 8             Yes               Yes     Fiber optic                   No  ...
# 9             Yes                No             DSL                  Yes  ...
# 10            Yes                No             DSL                  Yes  ...
# 11            Yes                No              No  No internet service  ...
# 12            Yes               Yes     Fiber optic                   No  ...
# 13            Yes               Yes     Fiber optic                   No  ...
# 14            Yes                No     Fiber optic                  Yes  ...
# 15            Yes               Yes     Fiber optic                  Yes  ...
# 16            Yes                No              No  No internet service  ...
# 17            Yes               Yes     Fiber optic                  Yes  ...
# 18            Yes                No             DSL                   No  ...
# 19            Yes                No     Fiber optic                   No  ...
# 20             No  No phone service             DSL                   No  ...
# 21            Yes                No              No  No internet service  ...
# 22            Yes                No              No  No internet service  ...
# 23            Yes               Yes             DSL                   No  ...
# 24            Yes                No             DSL                  Yes  ...
# 25            Yes                No             DSL                  Yes  ...
# 26            Yes               Yes     Fiber optic                   No  ...
# 27             No  No phone service             DSL                   No  ...
# 28            Yes               Yes             DSL                  Yes  ...
# 29            Yes                No             DSL                   No  ...
# ...           ...               ...             ...                  ...  ...
# 7013          Yes               Yes     Fiber optic                   No  ...
# 7014          Yes               Yes     Fiber optic                   No  ...
# 7015          Yes                No     Fiber optic                   No  ...
# 7016          Yes                No             DSL                   No  ...
# 7017          Yes                No              No  No internet service  ...
# 7018          Yes                No     Fiber optic                   No  ...
# 7019          Yes                No              No  No internet service  ...
# 7020          Yes                No              No  No internet service  ...
# 7021          Yes                No             DSL                   No  ...
# 7022          Yes               Yes     Fiber optic                   No  ...
# 7023          Yes               Yes     Fiber optic                   No  ...
# 7024          Yes               Yes     Fiber optic                  Yes  ...
# 7025          Yes               Yes     Fiber optic                   No  ...
# 7026          Yes                No             DSL                   No  ...
# 7027          Yes                No             DSL                   No  ...
# 7028          Yes                No             DSL                   No  ...
# 7029           No  No phone service             DSL                   No  ...
# 7030          Yes                No              No  No internet service  ...
# 7031          Yes               Yes             DSL                  Yes  ...
# 7032          Yes               Yes     Fiber optic                   No  ...
# 7033          Yes                No     Fiber optic                   No  ...
# 7034          Yes               Yes     Fiber optic                  Yes  ...
# 7035          Yes                No     Fiber optic                   No  ...
# 7036           No  No phone service             DSL                   No  ...
# 7037          Yes                No              No  No internet service  ...
# 7038          Yes               Yes             DSL                  Yes  ...
# 7039          Yes               Yes     Fiber optic                   No  ...
# 7040           No  No phone service             DSL                  Yes  ...
# 7041          Yes               Yes     Fiber optic                   No  ...
# 7042          Yes                No     Fiber optic                  Yes  ...
#
#          DeviceProtection          TechSupport          StreamingTV  \
# 0                      No                   No                   No
# 1                     Yes                   No                   No
# 2                      No                   No                   No
# 3                     Yes                  Yes                   No
# 4                      No                   No                   No
# 5                     Yes                   No                  Yes
# 6                      No                   No                  Yes
# 7                      No                   No                   No
# 8                     Yes                  Yes                  Yes
# 9                      No                   No                   No
# 10                     No                   No                   No
# 11    No internet service  No internet service  No internet service
# 12                    Yes                   No                  Yes
# 13                    Yes                   No                  Yes
# 14                    Yes                  Yes                  Yes
# 15                    Yes                  Yes                  Yes
# 16    No internet service  No internet service  No internet service
# 17                    Yes                   No                  Yes
# 18                    Yes                  Yes                   No
# 19                    Yes                   No                   No
# 20                    Yes                   No                   No
# 21    No internet service  No internet service  No internet service
# 22    No internet service  No internet service  No internet service
# 23                     No                  Yes                   No
# 24                     No                  Yes                   No
# 25                     No                   No                   No
# 26                     No                   No                  Yes
# 27                     No                   No                   No
# 28                    Yes                  Yes                  Yes
# 29                     No                   No                  Yes
# ...                   ...                  ...                  ...
# 7013                  Yes                   No                  Yes
# 7014                   No                   No                  Yes
# 7015                  Yes                   No                  Yes
# 7016                   No                   No                   No
# 7017  No internet service  No internet service  No internet service
# 7018                   No                   No                   No
# 7019  No internet service  No internet service  No internet service
# 7020  No internet service  No internet service  No internet service
# 7021                   No                  Yes                  Yes
# 7022                  Yes                   No                  Yes
# 7023                  Yes                   No                  Yes
# 7024                  Yes                   No                   No
# 7025                  Yes                  Yes                   No
# 7026                   No                   No                   No
# 7027                   No                  Yes                  Yes
# 7028                   No                  Yes                  Yes
# 7029                   No                   No                  Yes
# 7030  No internet service  No internet service  No internet service
# 7031                   No                   No                   No
# 7032                   No                   No                   No
# 7033                   No                   No                   No
# 7034                  Yes                   No                  Yes
# 7035                   No                   No                  Yes
# 7036                  Yes                  Yes                  Yes
# 7037  No internet service  No internet service  No internet service
# 7038                  Yes                  Yes                  Yes
# 7039                  Yes                   No                  Yes
# 7040                   No                   No                   No
# 7041                   No                   No                   No
# 7042                  Yes                  Yes                  Yes
#
#           StreamingMovies        Contract PaperlessBilling  \
# 0                      No  Month-to-month              Yes
# 1                      No        One year               No
# 2                      No  Month-to-month              Yes
# 3                      No        One year               No
# 4                      No  Month-to-month              Yes
# 5                     Yes  Month-to-month              Yes
# 6                      No  Month-to-month              Yes
# 7                      No  Month-to-month               No
# 8                     Yes  Month-to-month              Yes
# 9                      No        One year               No
# 10                     No  Month-to-month              Yes
# 11    No internet service        Two year               No
# 12                    Yes        One year               No
# 13                    Yes  Month-to-month              Yes
# 14                    Yes  Month-to-month              Yes
# 15                    Yes        Two year               No
# 16    No internet service        One year               No
# 17                    Yes        Two year               No
# 18                     No  Month-to-month               No
# 19                    Yes  Month-to-month              Yes
# 20                    Yes  Month-to-month              Yes
# 21    No internet service        One year               No
# 22    No internet service  Month-to-month               No
# 23                     No        Two year              Yes
# 24                     No  Month-to-month               No
# 25                     No  Month-to-month              Yes
# 26                    Yes  Month-to-month              Yes
# 27                     No  Month-to-month               No
# 28                    Yes        Two year              Yes
# 29                    Yes  Month-to-month              Yes
# ...                   ...             ...              ...
# 7013                   No  Month-to-month              Yes
# 7014                   No  Month-to-month              Yes
# 7015                   No  Month-to-month              Yes
# 7016                   No  Month-to-month               No
# 7017  No internet service        Two year               No
# 7018                   No  Month-to-month              Yes
# 7019  No internet service        Two year               No
# 7020  No internet service  Month-to-month              Yes
# 7021                   No        One year              Yes
# 7022                  Yes        One year              Yes
# 7023                  Yes  Month-to-month              Yes
# 7024                   No  Month-to-month              Yes
# 7025                  Yes  Month-to-month              Yes
# 7026                   No  Month-to-month              Yes
# 7027                  Yes  Month-to-month               No
# 7028                   No        Two year               No
# 7029                  Yes  Month-to-month              Yes
# 7030  No internet service  Month-to-month              Yes
# 7031                   No        One year               No
# 7032                   No  Month-to-month              Yes
# 7033                   No  Month-to-month              Yes
# 7034                   No  Month-to-month              Yes
# 7035                   No  Month-to-month              Yes
# 7036                  Yes        One year               No
# 7037  No internet service        Two year              Yes
# 7038                  Yes        One year              Yes
# 7039                  Yes        One year              Yes
# 7040                   No  Month-to-month              Yes
# 7041                   No  Month-to-month              Yes
# 7042                  Yes        Two year              Yes
#
#                   PaymentMethod MonthlyCharges  TotalCharges Churn
# 0              Electronic check          29.85         29.85    No
# 1                  Mailed check          56.95        1889.5    No
# 2                  Mailed check          53.85        108.15   Yes
# 3     Bank transfer (automatic)          42.30       1840.75    No
# 4              Electronic check          70.70        151.65   Yes
# 5              Electronic check          99.65         820.5   Yes
# 6       Credit card (automatic)          89.10        1949.4    No
# 7                  Mailed check          29.75         301.9    No
# 8              Electronic check         104.80       3046.05   Yes
# 9     Bank transfer (automatic)          56.15       3487.95    No
# 10                 Mailed check          49.95        587.45    No
# 11      Credit card (automatic)          18.95         326.8    No
# 12      Credit card (automatic)         100.35        5681.1    No
# 13    Bank transfer (automatic)         103.70        5036.3   Yes
# 14             Electronic check         105.50       2686.05    No
# 15      Credit card (automatic)         113.25       7895.15    No
# 16                 Mailed check          20.65       1022.95    No
# 17    Bank transfer (automatic)         106.70       7382.25    No
# 18      Credit card (automatic)          55.20        528.35   Yes
# 19             Electronic check          90.05        1862.9    No
# 20             Electronic check          39.65         39.65   Yes
# 21    Bank transfer (automatic)          19.80        202.25    No
# 22                 Mailed check          20.15         20.15   Yes
# 23      Credit card (automatic)          59.90        3505.1    No
# 24      Credit card (automatic)          59.60        2970.3    No
# 25    Bank transfer (automatic)          55.30        1530.6    No
# 26             Electronic check          99.35       4749.15   Yes
# 27             Electronic check          30.20          30.2   Yes
# 28      Credit card (automatic)          90.25       6369.45    No
# 29                 Mailed check          64.70        1093.1   Yes
# ...                         ...            ...           ...   ...
# 7013  Bank transfer (automatic)          93.40        3756.4    No
# 7014           Electronic check          89.20       3645.75    No
# 7015    Credit card (automatic)          85.20       2874.45    No
# 7016           Electronic check          49.95         49.95    No
# 7017  Bank transfer (automatic)          20.65       1020.75    No
# 7018               Mailed check          70.65         70.65   Yes
# 7019               Mailed check          20.15           826    No
# 7020           Electronic check          19.20           239    No
# 7021           Electronic check          59.80         727.8   Yes
# 7022           Electronic check         104.95        7544.3    No
# 7023           Electronic check         103.50        6479.4    No
# 7024    Credit card (automatic)          84.80       3626.35    No
# 7025  Bank transfer (automatic)          95.05        1679.4    No
# 7026  Bank transfer (automatic)          44.20        403.35   Yes
# 7027               Mailed check          73.35        931.55    No
# 7028  Bank transfer (automatic)          64.10       4326.25    No
# 7029           Electronic check          44.40        263.05    No
# 7030               Mailed check          20.05         39.25    No
# 7031    Credit card (automatic)          60.00        3316.1    No
# 7032           Electronic check          75.75         75.75   Yes
# 7033    Credit card (automatic)          69.50       2625.25    No
# 7034    Credit card (automatic)         102.95       6886.25   Yes
# 7035  Bank transfer (automatic)          78.70        1495.1    No
# 7036           Electronic check          60.65         743.3    No
# 7037  Bank transfer (automatic)          21.15        1419.4    No
# 7038               Mailed check          84.80        1990.5    No
# 7039    Credit card (automatic)         103.20        7362.9    No
# 7040           Electronic check          29.60        346.45    No
# 7041               Mailed check          74.40         306.6   Yes
# 7042  Bank transfer (automatic)         105.65        6844.5    No
#
# [7043 rows x 21 columns]

# %% [markdown]
# We have 7043 rows and 21 columns in our Dataset. We have a column named customerID, hence we will make this column as our index as it has no relevance in achieving our Model's prediction.

# %%
#Setting CustomerID as index
df.set_index('customerID',inplace=True)
df
# Out:
#             gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# customerID
# 7590-VHVEG  Female              0     Yes         No       1           No
# 5575-GNVDE    Male              0      No         No      34          Yes
# 3668-QPYBK    Male              0      No         No       2          Yes
# 7795-CFOCW    Male              0      No         No      45           No
# 9237-HQITU  Female              0      No         No       2          Yes
# 9305-CDSKC  Female              0      No         No       8          Yes
# 1452-KIOVK    Male              0      No        Yes      22          Yes
# 6713-OKOMC  Female              0      No         No      10           No
# 7892-POOKP  Female              0     Yes         No      28          Yes
# 6388-TABGU    Male              0      No        Yes      62          Yes
# 9763-GRSKD    Male              0     Yes        Yes      13          Yes
# 7469-LKBCI    Male              0      No         No      16          Yes
# 8091-TTVAX    Male              0     Yes         No      58          Yes
# 0280-XJGEX    Male              0      No         No      49          Yes
# 5129-JLPIS    Male              0      No         No      25          Yes
# 3655-SNQYZ  Female              0     Yes        Yes      69          Yes
# 8191-XWSZG  Female              0      No         No      52          Yes
# 9959-WOFKT    Male              0      No        Yes      71          Yes
# 4190-MFLUW  Female              0     Yes        Yes      10          Yes
# 4183-MYFRB  Female              0      No         No      21          Yes
# 8779-QRDMV    Male              1      No         No       1           No
# 1680-VDCWW    Male              0     Yes         No      12          Yes
# 1066-JKSGK    Male              0      No         No       1          Yes
# 3638-WEABW  Female              0     Yes         No      58          Yes
# 6322-HRPFA    Male              0     Yes        Yes      49          Yes
# 6865-JZNKO  Female              0      No         No      30          Yes
# 6467-CHFZW    Male              0     Yes        Yes      47          Yes
# 8665-UTDHZ    Male              0     Yes        Yes       1           No
# 5248-YGIJN    Male              0     Yes         No      72          Yes
# 8773-HHUOZ  Female              0      No        Yes      17          Yes
# ...            ...            ...     ...        ...     ...          ...
# 1685-BQULA  Female              0      No         No      40          Yes
# 9053-EJUNL    Male              0      No         No      41          Yes
# 0666-UXTJO    Male              1     Yes         No      34          Yes
# 1471-GIQKQ  Female              0      No         No       1          Yes
# 4807-IZYOZ  Female              0      No         No      51          Yes
# 1122-JWTJW    Male              0     Yes        Yes       1          Yes
# 9710-NJERN  Female              0      No         No      39          Yes
# 9837-FWLCH    Male              0     Yes        Yes      12          Yes
# 1699-HPSBG    Male              0      No         No      12          Yes
# 7203-OYKCT    Male              0      No         No      72          Yes
# 1035-IPQPU  Female              1     Yes         No      63          Yes
# 7398-LXGYX    Male              0     Yes         No      44          Yes
# 2823-LKABH  Female              0      No         No      18          Yes
# 8775-CEBBJ  Female              0      No         No       9          Yes
# 0550-DCXLH    Male              0      No         No      13          Yes
# 9281-CEDRU  Female              0     Yes         No      68          Yes
# 2235-DWLJU  Female              1      No         No       6           No
# 0871-OPBXW  Female              0      No         No       2          Yes
# 3605-JISKB    Male              1     Yes         No      55          Yes
# 6894-LFHLY    Male              1      No         No       1          Yes
# 9767-FFLEM    Male              0      No         No      38          Yes
# 0639-TSIQW  Female              0      No         No      67          Yes
# 8456-QDAVC    Male              0      No         No      19          Yes
# 7750-EYXWZ  Female              0      No         No      12           No
# 2569-WGERO  Female              0      No         No      72          Yes
# 6840-RESVB    Male              0     Yes        Yes      24          Yes
# 2234-XADUH  Female              0     Yes        Yes      72          Yes
# 4801-JZAZL  Female              0     Yes        Yes      11           No
# 8361-LTMKD    Male              1     Yes         No       4          Yes
# 3186-AJIEK    Male              0      No         No      66          Yes
#
#                MultipleLines InternetService       OnlineSecurity  \
# customerID
# 7590-VHVEG  No phone service             DSL                   No
# 5575-GNVDE                No             DSL                  Yes
# 3668-QPYBK                No             DSL                  Yes
# 7795-CFOCW  No phone service             DSL                  Yes
# 9237-HQITU                No     Fiber optic                   No
# 9305-CDSKC               Yes     Fiber optic                   No
# 1452-KIOVK               Yes     Fiber optic                   No
# 6713-OKOMC  No phone service             DSL                  Yes
# 7892-POOKP               Yes     Fiber optic                   No
# 6388-TABGU                No             DSL                  Yes
# 9763-GRSKD                No             DSL                  Yes
# 7469-LKBCI                No              No  No internet service
# 8091-TTVAX               Yes     Fiber optic                   No
# 0280-XJGEX               Yes     Fiber optic                   No
# 5129-JLPIS                No     Fiber optic                  Yes
# 3655-SNQYZ               Yes     Fiber optic                  Yes
# 8191-XWSZG                No              No  No internet service
# 9959-WOFKT               Yes     Fiber optic                  Yes
# 4190-MFLUW                No             DSL                   No
# 4183-MYFRB                No     Fiber optic                   No
# 8779-QRDMV  No phone service             DSL                   No
# 1680-VDCWW                No              No  No internet service
# 1066-JKSGK                No              No  No internet service
# 3638-WEABW               Yes             DSL                   No
# 6322-HRPFA                No             DSL                  Yes
# 6865-JZNKO                No             DSL                  Yes
# 6467-CHFZW               Yes     Fiber optic                   No
# 8665-UTDHZ  No phone service             DSL                   No
# 5248-YGIJN               Yes             DSL                  Yes
# 8773-HHUOZ                No             DSL                   No
# ...                      ...             ...                  ...
# 1685-BQULA               Yes     Fiber optic                   No
# 9053-EJUNL               Yes     Fiber optic                   No
# 0666-UXTJO                No     Fiber optic                   No
# 1471-GIQKQ                No             DSL                   No
# 4807-IZYOZ                No              No  No internet service
# 1122-JWTJW                No     Fiber optic                   No
# 9710-NJERN                No              No  No internet service
# 9837-FWLCH                No              No  No internet service
# 1699-HPSBG                No             DSL                   No
# 7203-OYKCT               Yes     Fiber optic                   No
# 1035-IPQPU               Yes     Fiber optic                   No
# 7398-LXGYX               Yes     Fiber optic                  Yes
# 2823-LKABH               Yes     Fiber optic                   No
# 8775-CEBBJ                No             DSL                   No
# 0550-DCXLH                No             DSL                   No
# 9281-CEDRU                No             DSL                   No
# 2235-DWLJU  No phone service             DSL                   No
# 0871-OPBXW                No              No  No internet service
# 3605-JISKB               Yes             DSL                  Yes
# 6894-LFHLY               Yes     Fiber optic                   No
# 9767-FFLEM                No     Fiber optic                   No
# 0639-TSIQW               Yes     Fiber optic                  Yes
# 8456-QDAVC                No     Fiber optic                   No
# 7750-EYXWZ  No phone service             DSL                   No
# 2569-WGERO                No              No  No internet service
# 6840-RESVB               Yes             DSL                  Yes
# 2234-XADUH               Yes     Fiber optic                   No
# 4801-JZAZL  No phone service             DSL                  Yes
# 8361-LTMKD               Yes     Fiber optic                   No
# 3186-AJIEK                No     Fiber optic                  Yes
#
#                    OnlineBackup     DeviceProtection          TechSupport  \
# customerID
# 7590-VHVEG                  Yes                   No                   No
# 5575-GNVDE                   No                  Yes                   No
# 3668-QPYBK                  Yes                   No                   No
# 7795-CFOCW                   No                  Yes                  Yes
# 9237-HQITU                   No                   No                   No
# 9305-CDSKC                   No                  Yes                   No
# 1452-KIOVK                  Yes                   No                   No
# 6713-OKOMC                   No                   No                   No
# 7892-POOKP                   No                  Yes                  Yes
# 6388-TABGU                  Yes                   No                   No
# 9763-GRSKD                   No                   No                   No
# 7469-LKBCI  No internet service  No internet service  No internet service
# 8091-TTVAX                   No                  Yes                   No
# 0280-XJGEX                  Yes                  Yes                   No
# 5129-JLPIS                   No                  Yes                  Yes
# 3655-SNQYZ                  Yes                  Yes                  Yes
# 8191-XWSZG  No internet service  No internet service  No internet service
# 9959-WOFKT                   No                  Yes                   No
# 4190-MFLUW                   No                  Yes                  Yes
# 4183-MYFRB                  Yes                  Yes                   No
# 8779-QRDMV                   No                  Yes                   No
# 1680-VDCWW  No internet service  No internet service  No internet service
# 1066-JKSGK  No internet service  No internet service  No internet service
# 3638-WEABW                  Yes                   No                  Yes
# 6322-HRPFA                  Yes                   No                  Yes
# 6865-JZNKO                  Yes                   No                   No
# 6467-CHFZW                  Yes                   No                   No
# 8665-UTDHZ                  Yes                   No                   No
# 5248-YGIJN                  Yes                  Yes                  Yes
# 8773-HHUOZ                   No                   No                   No
# ...                         ...                  ...                  ...
# 1685-BQULA                  Yes                  Yes                   No
# 9053-EJUNL                  Yes                   No                   No
# 0666-UXTJO                   No                  Yes                   No
# 1471-GIQKQ                  Yes                   No                   No
# 4807-IZYOZ  No internet service  No internet service  No internet service
# 1122-JWTJW                   No                   No                   No
# 9710-NJERN  No internet service  No internet service  No internet service
# 9837-FWLCH  No internet service  No internet service  No internet service
# 1699-HPSBG                   No                   No                  Yes
# 7203-OYKCT                  Yes                  Yes                   No
# 1035-IPQPU                  Yes                  Yes                   No
# 7398-LXGYX                   No                  Yes                   No
# 2823-LKABH                   No                  Yes                  Yes
# 8775-CEBBJ                   No                   No                   No
# 0550-DCXLH                  Yes                   No                  Yes
# 9281-CEDRU                  Yes                   No                  Yes
# 2235-DWLJU                   No                   No                   No
# 0871-OPBXW  No internet service  No internet service  No internet service
# 3605-JISKB                  Yes                   No                   No
# 6894-LFHLY                   No                   No                   No
# 9767-FFLEM                   No                   No                   No
# 0639-TSIQW                  Yes                  Yes                   No
# 8456-QDAVC                   No                   No                   No
# 7750-EYXWZ                  Yes                  Yes                  Yes
# 2569-WGERO  No internet service  No internet service  No internet service
# 6840-RESVB                   No                  Yes                  Yes
# 2234-XADUH                  Yes                  Yes                   No
# 4801-JZAZL                   No                   No                   No
# 8361-LTMKD                   No                   No                   No
# 3186-AJIEK                   No                  Yes                  Yes
#
#                     StreamingTV      StreamingMovies        Contract  \
# customerID
# 7590-VHVEG                   No                   No  Month-to-month
# 5575-GNVDE                   No                   No        One year
# 3668-QPYBK                   No                   No  Month-to-month
# 7795-CFOCW                   No                   No        One year
# 9237-HQITU                   No                   No  Month-to-month
# 9305-CDSKC                  Yes                  Yes  Month-to-month
# 1452-KIOVK                  Yes                   No  Month-to-month
# 6713-OKOMC                   No                   No  Month-to-month
# 7892-POOKP                  Yes                  Yes  Month-to-month
# 6388-TABGU                   No                   No        One year
# 9763-GRSKD                   No                   No  Month-to-month
# 7469-LKBCI  No internet service  No internet service        Two year
# 8091-TTVAX                  Yes                  Yes        One year
# 0280-XJGEX                  Yes                  Yes  Month-to-month
# 5129-JLPIS                  Yes                  Yes  Month-to-month
# 3655-SNQYZ                  Yes                  Yes        Two year
# 8191-XWSZG  No internet service  No internet service        One year
# 9959-WOFKT                  Yes                  Yes        Two year
# 4190-MFLUW                   No                   No  Month-to-month
# 4183-MYFRB                   No                  Yes  Month-to-month
# 8779-QRDMV                   No                  Yes  Month-to-month
# 1680-VDCWW  No internet service  No internet service        One year
# 1066-JKSGK  No internet service  No internet service  Month-to-month
# 3638-WEABW                   No                   No        Two year
# 6322-HRPFA                   No                   No  Month-to-month
# 6865-JZNKO                   No                   No  Month-to-month
# 6467-CHFZW                  Yes                  Yes  Month-to-month
# 8665-UTDHZ                   No                   No  Month-to-month
# 5248-YGIJN                  Yes                  Yes        Two year
# 8773-HHUOZ                  Yes                  Yes  Month-to-month
# ...                         ...                  ...             ...
# 1685-BQULA                  Yes                   No  Month-to-month
# 9053-EJUNL                  Yes                   No  Month-to-month
# 0666-UXTJO                  Yes                   No  Month-to-month
# 1471-GIQKQ                   No                   No  Month-to-month
# 4807-IZYOZ  No internet service  No internet service        Two year
# 1122-JWTJW                   No                   No  Month-to-month
# 9710-NJERN  No internet service  No internet service        Two year
# 9837-FWLCH  No internet service  No internet service  Month-to-month
# 1699-HPSBG                  Yes                   No        One year
# 7203-OYKCT                  Yes                  Yes        One year
# 1035-IPQPU                  Yes                  Yes  Month-to-month
# 7398-LXGYX                   No                   No  Month-to-month
# 2823-LKABH                   No                  Yes  Month-to-month
# 8775-CEBBJ                   No                   No  Month-to-month
# 0550-DCXLH                  Yes                  Yes  Month-to-month
# 9281-CEDRU                  Yes                   No        Two year
# 2235-DWLJU                  Yes                  Yes  Month-to-month
# 0871-OPBXW  No internet service  No internet service  Month-to-month
# 3605-JISKB                   No                   No        One year
# 6894-LFHLY                   No                   No  Month-to-month
# 9767-FFLEM                   No                   No  Month-to-month
# 0639-TSIQW                  Yes                   No  Month-to-month
# 8456-QDAVC                  Yes                   No  Month-to-month
# 7750-EYXWZ                  Yes                  Yes        One year
# 2569-WGERO  No internet service  No internet service        Two year
# 6840-RESVB                  Yes                  Yes        One year
# 2234-XADUH                  Yes                  Yes        One year
# 4801-JZAZL                   No                   No  Month-to-month
# 8361-LTMKD                   No                   No  Month-to-month
# 3186-AJIEK                  Yes                  Yes        Two year
#
#            PaperlessBilling              PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG              Yes           Electronic check           29.85
# 5575-GNVDE               No               Mailed check           56.95
# 3668-QPYBK              Yes               Mailed check           53.85
# 7795-CFOCW               No  Bank transfer (automatic)           42.30
# 9237-HQITU              Yes           Electronic check           70.70
# 9305-CDSKC              Yes           Electronic check           99.65
# 1452-KIOVK              Yes    Credit card (automatic)           89.10
# 6713-OKOMC               No               Mailed check           29.75
# 7892-POOKP              Yes           Electronic check          104.80
# 6388-TABGU               No  Bank transfer (automatic)           56.15
# 9763-GRSKD              Yes               Mailed check           49.95
# 7469-LKBCI               No    Credit card (automatic)           18.95
# 8091-TTVAX               No    Credit card (automatic)          100.35
# 0280-XJGEX              Yes  Bank transfer (automatic)          103.70
# 5129-JLPIS              Yes           Electronic check          105.50
# 3655-SNQYZ               No    Credit card (automatic)          113.25
# 8191-XWSZG               No               Mailed check           20.65
# 9959-WOFKT               No  Bank transfer (automatic)          106.70
# 4190-MFLUW               No    Credit card (automatic)           55.20
# 4183-MYFRB              Yes           Electronic check           90.05
# 8779-QRDMV              Yes           Electronic check           39.65
# 1680-VDCWW               No  Bank transfer (automatic)           19.80
# 1066-JKSGK               No               Mailed check           20.15
# 3638-WEABW              Yes    Credit card (automatic)           59.90
# 6322-HRPFA               No    Credit card (automatic)           59.60
# 6865-JZNKO              Yes  Bank transfer (automatic)           55.30
# 6467-CHFZW              Yes           Electronic check           99.35
# 8665-UTDHZ               No           Electronic check           30.20
# 5248-YGIJN              Yes    Credit card (automatic)           90.25
# 8773-HHUOZ              Yes               Mailed check           64.70
# ...                     ...                        ...             ...
# 1685-BQULA              Yes  Bank transfer (automatic)           93.40
# 9053-EJUNL              Yes           Electronic check           89.20
# 0666-UXTJO              Yes    Credit card (automatic)           85.20
# 1471-GIQKQ               No           Electronic check           49.95
# 4807-IZYOZ               No  Bank transfer (automatic)           20.65
# 1122-JWTJW              Yes               Mailed check           70.65
# 9710-NJERN               No               Mailed check           20.15
# 9837-FWLCH              Yes           Electronic check           19.20
# 1699-HPSBG              Yes           Electronic check           59.80
# 7203-OYKCT              Yes           Electronic check          104.95
# 1035-IPQPU              Yes           Electronic check          103.50
# 7398-LXGYX              Yes    Credit card (automatic)           84.80
# 2823-LKABH              Yes  Bank transfer (automatic)           95.05
# 8775-CEBBJ              Yes  Bank transfer (automatic)           44.20
# 0550-DCXLH               No               Mailed check           73.35
# 9281-CEDRU               No  Bank transfer (automatic)           64.10
# 2235-DWLJU              Yes           Electronic check           44.40
# 0871-OPBXW              Yes               Mailed check           20.05
# 3605-JISKB               No    Credit card (automatic)           60.00
# 6894-LFHLY              Yes           Electronic check           75.75
# 9767-FFLEM              Yes    Credit card (automatic)           69.50
# 0639-TSIQW              Yes    Credit card (automatic)          102.95
# 8456-QDAVC              Yes  Bank transfer (automatic)           78.70
# 7750-EYXWZ               No           Electronic check           60.65
# 2569-WGERO              Yes  Bank transfer (automatic)           21.15
# 6840-RESVB              Yes               Mailed check           84.80
# 2234-XADUH              Yes    Credit card (automatic)          103.20
# 4801-JZAZL              Yes           Electronic check           29.60
# 8361-LTMKD              Yes               Mailed check           74.40
# 3186-AJIEK              Yes  Bank transfer (automatic)          105.65
#
#            TotalCharges Churn
# customerID
# 7590-VHVEG        29.85    No
# 5575-GNVDE       1889.5    No
# 3668-QPYBK       108.15   Yes
# 7795-CFOCW      1840.75    No
# 9237-HQITU       151.65   Yes
# 9305-CDSKC        820.5   Yes
# 1452-KIOVK       1949.4    No
# 6713-OKOMC        301.9    No
# 7892-POOKP      3046.05   Yes
# 6388-TABGU      3487.95    No
# 9763-GRSKD       587.45    No
# 7469-LKBCI        326.8    No
# 8091-TTVAX       5681.1    No
# 0280-XJGEX       5036.3   Yes
# 5129-JLPIS      2686.05    No
# 3655-SNQYZ      7895.15    No
# 8191-XWSZG      1022.95    No
# 9959-WOFKT      7382.25    No
# 4190-MFLUW       528.35   Yes
# 4183-MYFRB       1862.9    No
# 8779-QRDMV        39.65   Yes
# 1680-VDCWW       202.25    No
# 1066-JKSGK        20.15   Yes
# 3638-WEABW       3505.1    No
# 6322-HRPFA       2970.3    No
# 6865-JZNKO       1530.6    No
# 6467-CHFZW      4749.15   Yes
# 8665-UTDHZ         30.2   Yes
# 5248-YGIJN      6369.45    No
# 8773-HHUOZ       1093.1   Yes
# ...                 ...   ...
# 1685-BQULA       3756.4    No
# 9053-EJUNL      3645.75    No
# 0666-UXTJO      2874.45    No
# 1471-GIQKQ        49.95    No
# 4807-IZYOZ      1020.75    No
# 1122-JWTJW        70.65   Yes
# 9710-NJERN          826    No
# 9837-FWLCH          239    No
# 1699-HPSBG        727.8   Yes
# 7203-OYKCT       7544.3    No
# 1035-IPQPU       6479.4    No
# 7398-LXGYX      3626.35    No
# 2823-LKABH       1679.4    No
# 8775-CEBBJ       403.35   Yes
# 0550-DCXLH       931.55    No
# 9281-CEDRU      4326.25    No
# 2235-DWLJU       263.05    No
# 0871-OPBXW        39.25    No
# 3605-JISKB       3316.1    No
# 6894-LFHLY        75.75   Yes
# 9767-FFLEM      2625.25    No
# 0639-TSIQW      6886.25   Yes
# 8456-QDAVC       1495.1    No
# 7750-EYXWZ        743.3    No
# 2569-WGERO       1419.4    No
# 6840-RESVB       1990.5    No
# 2234-XADUH       7362.9    No
# 4801-JZAZL       346.45    No
# 8361-LTMKD        306.6   Yes
# 3186-AJIEK       6844.5    No
#
# [7043 rows x 20 columns]

# %% [markdown]
# Now we have 7043 rows and 20 columns in our dataset.

# %% [markdown]
# # Checking Null Values & Treating Them

# %%
#Checking Null values
df.isnull().sum()
# Out:
# gender              0
# SeniorCitizen       0
# Partner             0
# Dependents          0
# tenure              0
# PhoneService        0
# MultipleLines       0
# InternetService     0
# OnlineSecurity      0
# OnlineBackup        0
# DeviceProtection    0
# TechSupport         0
# StreamingTV         0
# StreamingMovies     0
# Contract            0
# PaperlessBilling    0
# PaymentMethod       0
# MonthlyCharges      0
# TotalCharges        0
# Churn               0
# dtype: int64

# %%
#Visualizing null values through heatmap
import seaborn as sns
sns.heatmap(df.isnull())

# %% [markdown]
# There are no Null Values in our dataset. Hence, we can proceed forward with visualizing our data.

# %% [markdown]
# # Making DataFrame for the Nominal Data

# %%
#Copying nominal variables into a new dataframe
df_nominal=df[['gender', 'SeniorCitizen', 'Partner', 'Dependents','PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity','OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV','StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod','Churn']].copy()

# %%
#Checking columns of new nominal dataframe created
df_nominal.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'PhoneService',
#        'MultipleLines', 'InternetService', 'OnlineSecurity', 'OnlineBackup',
#        'DeviceProtection', 'TechSupport', 'StreamingTV', 'StreamingMovies',
#        'Contract', 'PaperlessBilling', 'PaymentMethod', 'Churn'],
#       dtype='object')

# %%
#Checking shape of nominal data
df_nominal.shape
# Out:
# (7043, 17)

# %% [markdown]
# The nominal/categorical data consists of 19 columns

# %% [markdown]
# # Visualization of Data

# %% [markdown]
# For the nominal categorical data we will use countplot as it will gives frequency of the columns.

# %%
#Importing Libraries for Visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Visualizing different columns using distplot
ncol,nrow=9,3
ab=df_nominal.columns.values
plt.figure(figsize=(20,30))
for index,i in enumerate(ab):
    ab=plt.subplot(ncol,nrow,index+1)
    sns.countplot(df[i])
    plt.title(f"plot {i}")
    plt.tight_layout()
plt.show()

# %% [markdown]
# Observations:
#
# The number of Male and Female customers are almsot equal.
#
# Around 5900 customers are not senior ctizens, but only around 1100 customers are senior citizens.
#
# Around 3400 customers have a partner but more than 3500 customers do not have a partner.
#
# Nearly around 5000 customers do not have any dependents but only around 2200 customers have dependents.
#
# Very less customers around 600 do not have a phone service but more than 6000 customers have a phone service.
#
# Around 3300 customers do not have multiple line service, around 700 have no phone service but around 2850 customers have multiple line service.
#
# 3000 customers have fibre optic Internet Service, 2400 have DSL and 1500 have no Internet Service.
#
# 3500 customers have no Online Security, 2000 have Online security and 1500 have no Internet Service.
#
# 2400 customers have online backup, 3000 have no Online Backup and 1500 have no Internet Service.
#
# 3150 customers do noy have any Device Protection, 2350 have Device Protection and 1500 have no Internet Service.
#
# Around 3450 customers have no Tech Support, 2000 have Tech Support and 1500 have no Internet Service.
#
# Around 3000 customers do not have Streaming TV, 2700 have Streaming TV and 1500 have no Internet Service.
#
# Around 2850 customers do not have Streaming Movies, 2750 have Streaming Movies and 1500 have no Internet Service.
#
# 3900 customers have a contract on month to month basis, 1500 have an yearly based contract and 1700 have contracts for 2 years.
#
# 4200 customers have a Paperless billing and only 2800 customers do not have a Paperless billing.
#
# Around 2400 customers make Payments through electronic check and around 1500 customers make payments via Mail Check, Bank Transfer and Credit Card each.
#
# More than 5000 customer's churn is no, only 1900 customer's churn is Yes.

# %% [markdown]
# # Making DataFrame of the Continuous type of Values

# %%
#Copying our continuous data into a new dataframe
df_continuous=df[['tenure','MonthlyCharges', 'TotalCharges']].copy()

# %%
#Checking columns of new continuous dataframe created
df_continuous.columns
# Out:
# Index(['tenure', 'MonthlyCharges', 'TotalCharges'], dtype='object')

# %%
#Checking shape of nominal data
df_continuous.shape
# Out:
# (7043, 3)

# %% [markdown]
# The continuous data consists of 3 columns.

# %%
#Univariate Analysis
df['tenure'].hist(grid=True)

# %% [markdown]
# Maximum customers have tenure between 0 to 7 and between 65 to 72.

# %%
sns.violinplot(x='MonthlyCharges',data=df)

# %% [markdown]
# Monthly charges are maximum in the range 15 to 25, less between 40 to 60 again reaches high between 75 to 105.

# %%
#Checking Data type of each column
df.dtypes
# Out:
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %% [markdown]
# As we can see that the Variable 'TotalCharges' is of the object datatype. To Visualize this data we will have to encode our data and convert all object variables into float values.

# %% [markdown]
# # Encoding of DataFrame

# %%
#Importing library for encoding and creating instance for the same 
from sklearn.preprocessing import OrdinalEncoder
enc=OrdinalEncoder()

# %%
#Converting object datatype into float values
for i in df.columns:
    if df[i].dtypes=='object':
        df[i]=enc.fit_transform(df[i].values.reshape(-1,1))

# %%
#Verifying Conversion 
df.head()
# Out:
#             gender  SeniorCitizen  Partner  Dependents  tenure  PhoneService  \
# customerID
# 7590-VHVEG     0.0              0      1.0         0.0       1           0.0
# 5575-GNVDE     1.0              0      0.0         0.0      34           1.0
# 3668-QPYBK     1.0              0      0.0         0.0       2           1.0
# 7795-CFOCW     1.0              0      0.0         0.0      45           0.0
# 9237-HQITU     0.0              0      0.0         0.0       2           1.0
#
#             MultipleLines  InternetService  OnlineSecurity  OnlineBackup  \
# customerID
# 7590-VHVEG            1.0              0.0             0.0           2.0
# 5575-GNVDE            0.0              0.0             2.0           0.0
# 3668-QPYBK            0.0              0.0             2.0           2.0
# 7795-CFOCW            1.0              0.0             2.0           0.0
# 9237-HQITU            0.0              1.0             0.0           0.0
#
#             DeviceProtection  TechSupport  StreamingTV  StreamingMovies  \
# customerID
# 7590-VHVEG               0.0          0.0          0.0              0.0
# 5575-GNVDE               2.0          0.0          0.0              0.0
# 3668-QPYBK               0.0          0.0          0.0              0.0
# 7795-CFOCW               2.0          2.0          0.0              0.0
# 9237-HQITU               0.0          0.0          0.0              0.0
#
#             Contract  PaperlessBilling  PaymentMethod  MonthlyCharges  \
# customerID
# 7590-VHVEG       0.0               1.0            2.0           29.85
# 5575-GNVDE       1.0               0.0            3.0           56.95
# 3668-QPYBK       0.0               1.0            3.0           53.85
# 7795-CFOCW       1.0               0.0            0.0           42.30
# 9237-HQITU       0.0               1.0            2.0           70.70
#
#             TotalCharges  Churn
# customerID
# 7590-VHVEG        2505.0    0.0
# 5575-GNVDE        1466.0    0.0
# 3668-QPYBK         157.0    1.0
# 7795-CFOCW        1400.0    0.0
# 9237-HQITU         925.0    1.0

# %% [markdown]
# We can observe that our object datatype has been converted into float values.

# %% [markdown]
# # Visualizing Variable TotalCharges

# %%
sns.violinplot(x='TotalCharges',data=df)

# %% [markdown]
# The values of TotalCharges are in between the range 500 and 6500 constantly.

# %% [markdown]
# # Describe Data

# %%
#Describing final columns present in dataset
df.columns
# Out:
# Index(['gender', 'SeniorCitizen', 'Partner', 'Dependents', 'tenure',
#        'PhoneService', 'MultipleLines', 'InternetService', 'OnlineSecurity',
#        'OnlineBackup', 'DeviceProtection', 'TechSupport', 'StreamingTV',
#        'StreamingMovies', 'Contract', 'PaperlessBilling', 'PaymentMethod',
#        'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
#Defining Shape of Dataframe
df.shape
# Out:
# (7043, 20)

# %%
#Getting data information
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7043 entries, 7590-VHVEG to 3186-AJIEK
# Data columns (total 20 columns):
# gender              7043 non-null float64
# SeniorCitizen       7043 non-null int64
# Partner             7043 non-null float64
# Dependents          7043 non-null float64
# tenure              7043 non-null int64
# PhoneService        7043 non-null float64
# MultipleLines       7043 non-null float64
# InternetService     7043 non-null float64
# OnlineSecurity      7043 non-null float64
# OnlineBackup        7043 non-null float64
# DeviceProtection    7043 non-null float64
# TechSupport         7043 non-null float64
# StreamingTV         7043 non-null float64
# StreamingMovies     7043 non-null float64
# Contract            7043 non-null float64
# PaperlessBilling    7043 non-null float64
# PaymentMethod       7043 non-null float64
# MonthlyCharges      7043 non-null float64
# TotalCharges        7043 non-null float64
# Churn               7043 non-null float64
# dtypes: float64(18), int64(2)
# memory usage: 1.4+ MB

# %% [markdown]
# We have 7043 rows, 20 columns in our dataset with no null values present and the values are in the Float/int data type. Hence, we can move forward with finding correlations in the data.

# %%
#Describing mean, median, min, max values of data
df.describe()
# Out:
#             gender  SeniorCitizen      Partner   Dependents       tenure  \
# count  7043.000000    7043.000000  7043.000000  7043.000000  7043.000000
# mean      0.504756       0.162147     0.483033     0.299588    32.371149
# std       0.500013       0.368612     0.499748     0.458110    24.559481
# min       0.000000       0.000000     0.000000     0.000000     0.000000
# 25%       0.000000       0.000000     0.000000     0.000000     9.000000
# 50%       1.000000       0.000000     0.000000     0.000000    29.000000
# 75%       1.000000       0.000000     1.000000     1.000000    55.000000
# max       1.000000       1.000000     1.000000     1.000000    72.000000
#
#        PhoneService  MultipleLines  InternetService  OnlineSecurity  \
# count   7043.000000    7043.000000      7043.000000     7043.000000
# mean       0.903166       0.940508         0.872923        0.790004
# std        0.295752       0.948554         0.737796        0.859848
# min        0.000000       0.000000         0.000000        0.000000
# 25%        1.000000       0.000000         0.000000        0.000000
# 50%        1.000000       1.000000         1.000000        1.000000
# 75%        1.000000       2.000000         1.000000        2.000000
# max        1.000000       2.000000         2.000000        2.000000
#
#        OnlineBackup  DeviceProtection  TechSupport  StreamingTV  \
# count   7043.000000       7043.000000  7043.000000  7043.000000
# mean       0.906432          0.904444     0.797104     0.985376
# std        0.880162          0.879949     0.861551     0.885002
# min        0.000000          0.000000     0.000000     0.000000
# 25%        0.000000          0.000000     0.000000     0.000000
# 50%        1.000000          1.000000     1.000000     1.000000
# 75%        2.000000          2.000000     2.000000     2.000000
# max        2.000000          2.000000     2.000000     2.000000
#
#        StreamingMovies     Contract  PaperlessBilling  PaymentMethod  \
# count      7043.000000  7043.000000       7043.000000    7043.000000
# mean          0.992475     0.690473          0.592219       1.574329
# std           0.885091     0.833755          0.491457       1.068104
# min           0.000000     0.000000          0.000000       0.000000
# 25%           0.000000     0.000000          0.000000       1.000000
# 50%           1.000000     0.000000          1.000000       2.000000
# 75%           2.000000     1.000000          1.000000       2.000000
# max           2.000000     2.000000          1.000000       3.000000
#
#        MonthlyCharges  TotalCharges        Churn
# count     7043.000000   7043.000000  7043.000000
# mean        64.761692   3257.794122     0.265370
# std         30.090047   1888.693496     0.441561
# min         18.250000      0.000000     0.000000
# 25%         35.500000   1609.000000     0.000000
# 50%         70.350000   3249.000000     0.000000
# 75%         89.850000   4901.500000     1.000000
# max        118.750000   6530.000000     1.000000

# %% [markdown]
# Let's try understanding the above data using Visualization to get a better idea.

# %%
#Visualizing data description
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True,linewidths=0.1,linecolor='blue',fmt='0.2f')

# %% [markdown]
# Observation:
#
# The standard deviation of almost all columns is very less which means that the data is not largely scattered, shows a normal distribution and does not contain skewness.
#
# Only columns tenure, Monthly Charges and Total Charges show high standard deviation.
#
# The values are high only in the Total Charges variable which contains maximum value at 6530 within the column.
#
# As most of our data consists of the string datatype values so we dont see any chance of having outliers in the data.

# %% [markdown]
# # Correlation of Columns with the Target Variable

# %%
df.corr()
# Out:
#                     gender  SeniorCitizen   Partner  Dependents    tenure  \
# gender            1.000000      -0.001874 -0.001808    0.010517  0.005106
# SeniorCitizen    -0.001874       1.000000  0.016479   -0.211185  0.016567
# Partner          -0.001808       0.016479  1.000000    0.452676  0.379697
# Dependents        0.010517      -0.211185  0.452676    1.000000  0.159712
# tenure            0.005106       0.016567  0.379697    0.159712  1.000000
# PhoneService     -0.006488       0.008576  0.017706   -0.001762  0.008448
# MultipleLines    -0.006739       0.146185  0.142410   -0.024991  0.343032
# InternetService  -0.000863      -0.032310  0.000891    0.044590 -0.030359
# OnlineSecurity   -0.015017      -0.128221  0.150828    0.152166  0.325468
# OnlineBackup     -0.012057      -0.013632  0.153130    0.091015  0.370876
# DeviceProtection  0.000549      -0.021398  0.166330    0.080537  0.371105
# TechSupport      -0.006825      -0.151268  0.126733    0.133524  0.322942
# StreamingTV      -0.006421       0.030776  0.137341    0.046885  0.289373
# StreamingMovies  -0.008743       0.047266  0.129574    0.021321  0.296866
# Contract          0.000126      -0.142554  0.294806    0.243187  0.671607
# PaperlessBilling -0.011754       0.156530 -0.014877   -0.111377  0.006152
# PaymentMethod     0.017352      -0.038551 -0.154798   -0.040292 -0.370436
# MonthlyCharges   -0.014569       0.220173  0.096848   -0.113890  0.247900
# TotalCharges     -0.005291       0.037653  0.059568   -0.009572  0.158523
# Churn            -0.008612       0.150889 -0.150448   -0.164221 -0.352229
#
#                   PhoneService  MultipleLines  InternetService  \
# gender               -0.006488      -0.006739        -0.000863
# SeniorCitizen         0.008576       0.146185        -0.032310
# Partner               0.017706       0.142410         0.000891
# Dependents           -0.001762      -0.024991         0.044590
# tenure                0.008448       0.343032        -0.030359
# PhoneService          1.000000      -0.020538         0.387436
# MultipleLines        -0.020538       1.000000        -0.109216
# InternetService       0.387436      -0.109216         1.000000
# OnlineSecurity       -0.015198       0.007141        -0.028416
# OnlineBackup          0.024105       0.117327         0.036138
# DeviceProtection      0.003727       0.122318         0.044944
# TechSupport          -0.019158       0.011466        -0.026047
# StreamingTV           0.055353       0.175059         0.107417
# StreamingMovies       0.043870       0.180957         0.098350
# Contract              0.002247       0.110842         0.099721
# PaperlessBilling      0.016505       0.165146        -0.138625
# PaymentMethod        -0.004184      -0.176793         0.086140
# MonthlyCharges        0.247398       0.433576        -0.323260
# TotalCharges          0.083195       0.114955        -0.055724
# Churn                 0.011942       0.038037        -0.047291
#
#                   OnlineSecurity  OnlineBackup  DeviceProtection  TechSupport  \
# gender                 -0.015017     -0.012057          0.000549    -0.006825
# SeniorCitizen          -0.128221     -0.013632         -0.021398    -0.151268
# Partner                 0.150828      0.153130          0.166330     0.126733
# Dependents              0.152166      0.091015          0.080537     0.133524
# tenure                  0.325468      0.370876          0.371105     0.322942
# PhoneService           -0.015198      0.024105          0.003727    -0.019158
# MultipleLines           0.007141      0.117327          0.122318     0.011466
# InternetService        -0.028416      0.036138          0.044944    -0.026047
# OnlineSecurity          1.000000      0.185126          0.175985     0.285028
# OnlineBackup            0.185126      1.000000          0.187757     0.195748
# DeviceProtection        0.175985      0.187757          1.000000     0.240593
# TechSupport             0.285028      0.195748          0.240593     1.000000
# StreamingTV             0.044669      0.147186          0.276652     0.161305
# StreamingMovies         0.055954      0.136722          0.288799     0.161316
# Contract                0.374416      0.280980          0.350277     0.425367
# PaperlessBilling       -0.157641     -0.013370         -0.038234    -0.113600
# PaymentMethod          -0.096726     -0.124847         -0.135750    -0.104670
# MonthlyCharges         -0.053878      0.119777          0.163652    -0.008682
# TotalCharges            0.042357      0.090756          0.105905     0.057488
# Churn                  -0.289309     -0.195525         -0.178134    -0.282492
#
#                   StreamingTV  StreamingMovies  Contract  PaperlessBilling  \
# gender              -0.006421        -0.008743  0.000126         -0.011754
# SeniorCitizen        0.030776         0.047266 -0.142554          0.156530
# Partner              0.137341         0.129574  0.294806         -0.014877
# Dependents           0.046885         0.021321  0.243187         -0.111377
# tenure               0.289373         0.296866  0.671607          0.006152
# PhoneService         0.055353         0.043870  0.002247          0.016505
# MultipleLines        0.175059         0.180957  0.110842          0.165146
# InternetService      0.107417         0.098350  0.099721         -0.138625
# OnlineSecurity       0.044669         0.055954  0.374416         -0.157641
# OnlineBackup         0.147186         0.136722  0.280980         -0.013370
# DeviceProtection     0.276652         0.288799  0.350277         -0.038234
# TechSupport          0.161305         0.161316  0.425367         -0.113600
# StreamingTV          1.000000         0.434772  0.227116          0.096642
# StreamingMovies      0.434772         1.000000  0.231226          0.083700
# Contract             0.227116         0.231226  1.000000         -0.176733
# PaperlessBilling     0.096642         0.083700 -0.176733          1.000000
# PaymentMethod       -0.104234        -0.111241 -0.227543         -0.062904
# MonthlyCharges       0.336706         0.335459 -0.074195          0.352150
# TotalCharges         0.138173         0.145366  0.106178          0.100957
# Churn               -0.036581        -0.038492 -0.396713          0.191825
#
#                   PaymentMethod  MonthlyCharges  TotalCharges     Churn
# gender                 0.017352       -0.014569     -0.005291 -0.008612
# SeniorCitizen         -0.038551        0.220173      0.037653  0.150889
# Partner               -0.154798        0.096848      0.059568 -0.150448
# Dependents            -0.040292       -0.113890     -0.009572 -0.164221
# tenure                -0.370436        0.247900      0.158523 -0.352229
# PhoneService          -0.004184        0.247398      0.083195  0.011942
# MultipleLines         -0.176793        0.433576      0.114955  0.038037
# InternetService        0.086140       -0.323260     -0.055724 -0.047291
# OnlineSecurity        -0.096726       -0.053878      0.042357 -0.289309
# OnlineBackup          -0.124847        0.119777      0.090756 -0.195525
# DeviceProtection      -0.135750        0.163652      0.105905 -0.178134
# TechSupport           -0.104670       -0.008682      0.057488 -0.282492
# StreamingTV           -0.104234        0.336706      0.138173 -0.036581
# StreamingMovies       -0.111241        0.335459      0.145366 -0.038492
# Contract              -0.227543       -0.074195      0.106178 -0.396713
# PaperlessBilling      -0.062904        0.352150      0.100957  0.191825
# PaymentMethod          1.000000       -0.193407     -0.067477  0.107062
# MonthlyCharges        -0.193407        1.000000      0.279875  0.193356
# TotalCharges          -0.067477        0.279875      1.000000  0.014479
# Churn                  0.107062        0.193356      0.014479  1.000000

# %% [markdown]
# We can observe both positive and negative correlations within the data. Let's visualize these correlations to get a better understanding of data.

# %%
#Plotting correlation of input features with the target Variable
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(),annot=True,linewidths=0.1,linecolor='black',fmt='0.2f')

# %% [markdown]
# Observation:
#
# The Target Variable Churn is most positively correlated with variables MonthlyCharges & PaperlessBilling.
#
# The Target Variable Churn is most negatively correlated with variables tenure & Contract.
#
# We can observe that the negative correlations are much more stronger than the positive correlations.

# %%
#Sorting correlation in order with the Target Variable
corr_matrix=df.corr()
corr_matrix['Churn'].sort_values(ascending=False)
# Out:
# Churn               1.000000
# MonthlyCharges      0.193356
# PaperlessBilling    0.191825
# SeniorCitizen       0.150889
# PaymentMethod       0.107062
# MultipleLines       0.038037
# TotalCharges        0.014479
# PhoneService        0.011942
# gender             -0.008612
# StreamingTV        -0.036581
# StreamingMovies    -0.038492
# InternetService    -0.047291
# Partner            -0.150448
# Dependents         -0.164221
# DeviceProtection   -0.178134
# OnlineBackup       -0.195525
# TechSupport        -0.282492
# OnlineSecurity     -0.289309
# tenure             -0.352229
# Contract           -0.396713
# Name: Churn, dtype: float64

# %% [markdown]
# The positively correlated columns with the Target Variable are MonthlyCharges, PaperlessBilling, SeniorCitizen, PaymentMethod, MultipleLines, TotalCharges & PhoneService.
#
# The negatively correlated columns with the Target Variable are gender, StreamingTV, StreamingMovies, InternetService, Partner, Dependents, DeviceProtection, OnlineBackup, TechSupport, OnlineSecurity, tenure & Contract.

# %% [markdown]
# Most columns are negatively correlated with the Target Variable whereas hardly some are positively correlated.

# %% [markdown]
# # Checking Skewness

# %%
#Checking Skewness
df.skew()
# Out:
# gender             -0.019031
# SeniorCitizen       1.833633
# Partner             0.067922
# Dependents          0.875199
# tenure              0.239540
# PhoneService       -2.727153
# MultipleLines       0.118719
# InternetService     0.205423
# OnlineSecurity      0.416985
# OnlineBackup        0.182930
# DeviceProtection    0.186847
# TechSupport         0.402365
# StreamingTV         0.028486
# StreamingMovies     0.014657
# Contract            0.630959
# PaperlessBilling   -0.375396
# PaymentMethod      -0.170129
# MonthlyCharges     -0.220524
# TotalCharges        0.015857
# Churn               1.063031
# dtype: float64

# %% [markdown]
# Keeping threshold +/-0.5 as the range for skewness, we can see that the variables that are showing skewness in it's values are of the string datatype, hence we don't consider this as skewness present in values.
#
# The continuous type of variables such as tenure, Monthly Charges & Total Charges are not showing any skewness in it's values.
#
# Hence, we don't have skewness present in our data. The data is not skewed so we will not remove the skewness.

# %%
#Visualizing skewness on density graph
#Example of multi variate analysis
df.plot(kind='density',subplots=True,layout=(4,10),legend=False,sharex=False,figsize=(30,20))
plt.show()

# %% [markdown]
# We can see that our data is not showing skewness in any of the columns from the above graph.

# %% [markdown]
# # Check Outliers

# %%
#Visualizing outliers of different variables
collist=df.columns.values
ncol=10
nrows=10
plt.figure(figsize=(ncol,5*ncol))
for i in range(1,len(collist)):
    plt.subplot(nrows,ncol,i+1)
    sns.boxplot(df[collist[i]],color='green',orient='v')
    plt.tight_layout()
# Out:
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '
# C:\Users\HP-15\Anaconda3\lib\site-packages\seaborn\_core.py:1326: UserWarning: Vertical orientation ignored with only `x` specified.
#   warnings.warn(single_var_warning.format("Vertical", "x"))
# C:\Users\HP-15\Anaconda3\lib\site-packages\matplotlib\tight_layout.py:199: UserWarning: Tight layout not applied. tight_layout cannot make axes width small enough to accommodate all axes decorations
#   warnings.warn('Tight layout not applied. '

# %% [markdown]
# Since we do not see any outliers present in our dataset, we will proceed forward with training data.

# %% [markdown]
# # Separating the column into x & y

# %%
#Creating x & y columns 
x=df.drop('Churn',axis=1)
y=df['Churn']

# %% [markdown]
# Separating the columns into x & y as input featues and target variable respectively.

# %% [markdown]
# # Scaling Data using Min Max Scaler

# %%
#Importing libraries for Min Max Scaler
from sklearn.preprocessing import MinMaxScaler
import warnings
warnings.filterwarnings('ignore')

# %%
#define min max scaler
mms=MinMaxScaler()
# transform data
ab=mms.fit_transform(df)
print(ab)
# Out:
# [[0.         0.         1.         ... 0.11542289 0.38361409 0.        ]
#  [1.         0.         0.         ... 0.38507463 0.2245023  0.        ]
#  [1.         0.         0.         ... 0.35422886 0.02404288 1.        ]
#  ...
#  [0.         0.         1.         ... 0.11293532 0.45849923 0.        ]
#  [1.         1.         1.         ... 0.55870647 0.40735069 1.        ]
#  [1.         0.         0.         ... 0.86965174 0.8280245  0.        ]]

# %% [markdown]
# Hence, the data is Scaled.

# %% [markdown]
# Since our Target Variable has binary values, we use Classification Algorithms.

# %% [markdown]
# # Model Building

# %%
#importing Libraries for buiding model
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
#Code for finding best random state
lr=LogisticRegression()
for i in range(0,200):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train,y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f'At random state {i}, the training accuracy is: {accuracy_score(y_train,pred_train)}')
    print(f'At random state {i}, the testing accuracy is: {accuracy_score(y_test,pred_test)}')
    print("\n")
# Out:
# At random state 0, the training accuracy is: 0.8074192403265885
# At random state 0, the testing accuracy is: 0.794889992902768
#
#
# At random state 1, the training accuracy is: 0.8022719204827831
# At random state 1, the testing accuracy is: 0.8069552874378992
#
#
# At random state 2, the training accuracy is: 0.80386936457224
# At random state 2, the testing accuracy is: 0.8076650106458482
#
#
# At random state 3, the training accuracy is: 0.8019169329073482
# At random state 3, the testing accuracy is: 0.815471965933286
#
#
# At random state 4, the training accuracy is: 0.8061767838125665
# At random state 4, the testing accuracy is: 0.7849538679914834
#
#
# At random state 5, the training accuracy is: 0.805111821086262
# At random state 5, the testing accuracy is: 0.7977288857345636
#
#
# At random state 6, the training accuracy is: 0.805111821086262
# At random state 6, the testing accuracy is: 0.8026969481902059
#
#
# At random state 7, the training accuracy is: 0.8035143769968051
# At random state 7, the testing accuracy is: 0.8140525195173882
#
#
# At random state 8, the training accuracy is: 0.8118565850195243
# At random state 8, the testing accuracy is: 0.7828246983676366
#
#
# At random state 9, the training accuracy is: 0.8056443024494143
# At random state 9, the testing accuracy is: 0.794889992902768
#
#
# At random state 10, the training accuracy is: 0.8044018459353922
# At random state 10, the testing accuracy is: 0.8069552874378992
#
#
# At random state 11, the training accuracy is: 0.8067092651757188
# At random state 11, the testing accuracy is: 0.8005677785663591
#
#
# At random state 12, the training accuracy is: 0.805111821086262
# At random state 12, the testing accuracy is: 0.8005677785663591
#
#
# At random state 13, the training accuracy is: 0.8042243521476748
# At random state 13, the testing accuracy is: 0.808374733853797
#
#
# At random state 14, the training accuracy is: 0.7978345757898474
# At random state 14, the testing accuracy is: 0.8183108587650816
#
#
# At random state 15, the training accuracy is: 0.806354277600284
# At random state 15, the testing accuracy is: 0.7963094393186657
#
#
# At random state 16, the training accuracy is: 0.8035143769968051
# At random state 16, the testing accuracy is: 0.8133427963094393
#
#
# At random state 17, the training accuracy is: 0.8056443024494143
# At random state 17, the testing accuracy is: 0.7977288857345636
#
#
# At random state 18, the training accuracy is: 0.7988995385161519
# At random state 18, the testing accuracy is: 0.8232789212207239
#
#
# At random state 19, the training accuracy is: 0.8042243521476748
# At random state 19, the testing accuracy is: 0.8055358410220014
#
#
# At random state 20, the training accuracy is: 0.7990770323038694
# At random state 20, the testing accuracy is: 0.8176011355571328
#
#
# At random state 21, the training accuracy is: 0.8068867589634363
# At random state 21, the testing accuracy is: 0.7963094393186657
#
#
# At random state 22, the training accuracy is: 0.8106141285055023
# At random state 22, the testing accuracy is: 0.7814052519517388
#
#
# At random state 23, the training accuracy is: 0.80386936457224
# At random state 23, the testing accuracy is: 0.8069552874378992
#
#
# At random state 24, the training accuracy is: 0.7988995385161519
# At random state 24, the testing accuracy is: 0.8225691980127751
#
#
# At random state 25, the training accuracy is: 0.8022719204827831
# At random state 25, the testing accuracy is: 0.8119233498935415
#
#
# At random state 26, the training accuracy is: 0.8045793397231097
# At random state 26, the testing accuracy is: 0.8076650106458482
#
#
# At random state 27, the training accuracy is: 0.8036918707845225
# At random state 27, the testing accuracy is: 0.8005677785663591
#
#
# At random state 28, the training accuracy is: 0.8044018459353922
# At random state 28, the testing accuracy is: 0.8026969481902059
#
#
# At random state 29, the training accuracy is: 0.8102591409300675
# At random state 29, the testing accuracy is: 0.7863733144073811
#
#
# At random state 30, the training accuracy is: 0.8083067092651757
# At random state 30, the testing accuracy is: 0.7934705464868701
#
#
# At random state 31, the training accuracy is: 0.8019169329073482
# At random state 31, the testing accuracy is: 0.8105039034776437
#
#
# At random state 32, the training accuracy is: 0.8084842030528931
# At random state 32, the testing accuracy is: 0.7899219304471257
#
#
# At random state 33, the training accuracy is: 0.8036918707845225
# At random state 33, the testing accuracy is: 0.7998580553584103
#
#
# At random state 34, the training accuracy is: 0.81008164714235
# At random state 34, the testing accuracy is: 0.7785663591199432
#
#
# At random state 35, the training accuracy is: 0.8006744763933262
# At random state 35, the testing accuracy is: 0.8218594748048261
#
#
# At random state 36, the training accuracy is: 0.8072417465388712
# At random state 36, the testing accuracy is: 0.7899219304471257
#
#
# At random state 37, the training accuracy is: 0.8059992900248492
# At random state 37, the testing accuracy is: 0.8026969481902059
#
#
# At random state 38, the training accuracy is: 0.8049343272985445
# At random state 38, the testing accuracy is: 0.8034066713981547
#
#
# At random state 39, the training accuracy is: 0.8036918707845225
# At random state 39, the testing accuracy is: 0.808374733853797
#
#
# At random state 40, the training accuracy is: 0.8070642527511537
# At random state 40, the testing accuracy is: 0.7913413768630234
#
#
# At random state 41, the training accuracy is: 0.8070642527511537
# At random state 41, the testing accuracy is: 0.7885024840312278
#
#
# At random state 42, the training accuracy is: 0.8028044018459354
# At random state 42, the testing accuracy is: 0.8168914123491838
#
#
# At random state 43, the training accuracy is: 0.8035143769968051
# At random state 43, the testing accuracy is: 0.8097941802696949
#
#
# At random state 44, the training accuracy is: 0.8052893148739794
# At random state 44, the testing accuracy is: 0.7991483321504613
#
#
# At random state 45, the training accuracy is: 0.8031593894213702
# At random state 45, the testing accuracy is: 0.8126330731014905
#
#
# At random state 46, the training accuracy is: 0.8054668086616968
# At random state 46, the testing accuracy is: 0.8076650106458482
#
#
# At random state 47, the training accuracy is: 0.8084842030528931
# At random state 47, the testing accuracy is: 0.794180269694819
#
#
# At random state 48, the training accuracy is: 0.8036918707845225
# At random state 48, the testing accuracy is: 0.8026969481902059
#
#
# At random state 49, the training accuracy is: 0.8045793397231097
# At random state 49, the testing accuracy is: 0.8090844570617459
#
#
# At random state 50, the training accuracy is: 0.8042243521476748
# At random state 50, the testing accuracy is: 0.8005677785663591
#
#
# At random state 51, the training accuracy is: 0.8020944266950657
# At random state 51, the testing accuracy is: 0.801277501774308
#
#
# At random state 52, the training accuracy is: 0.8022719204827831
# At random state 52, the testing accuracy is: 0.8112136266855926
#
#
# At random state 53, the training accuracy is: 0.8006744763933262
# At random state 53, the testing accuracy is: 0.8090844570617459
#
#
# At random state 54, the training accuracy is: 0.8065317713880015
# At random state 54, the testing accuracy is: 0.7984386089425124
#
#
# At random state 55, the training accuracy is: 0.8049343272985445
# At random state 55, the testing accuracy is: 0.7991483321504613
#
#
# At random state 56, the training accuracy is: 0.8017394391196309
# At random state 56, the testing accuracy is: 0.815471965933286
#
#
# At random state 57, the training accuracy is: 0.8006744763933262
# At random state 57, the testing accuracy is: 0.8147622427253371
#
#
# At random state 58, the training accuracy is: 0.8052893148739794
# At random state 58, the testing accuracy is: 0.8048261178140526
#
#
# At random state 59, the training accuracy is: 0.7999645012424565
# At random state 59, the testing accuracy is: 0.8183108587650816
#
#
# At random state 60, the training accuracy is: 0.8070642527511537
# At random state 60, the testing accuracy is: 0.7899219304471257
#
#
# At random state 61, the training accuracy is: 0.8045793397231097
# At random state 61, the testing accuracy is: 0.8041163946061036
#
#
# At random state 62, the training accuracy is: 0.802626908058218
# At random state 62, the testing accuracy is: 0.8112136266855926
#
#
# At random state 63, the training accuracy is: 0.8084842030528931
# At random state 63, the testing accuracy is: 0.7927608232789212
# At random state 64, the training accuracy is: 0.8042243521476748
# At random state 64, the testing accuracy is: 0.8041163946061036
#
#
# At random state 65, the training accuracy is: 0.8049343272985445
# At random state 65, the testing accuracy is: 0.7991483321504613
#
#
# At random state 66, the training accuracy is: 0.8040468583599574
# At random state 66, the testing accuracy is: 0.8048261178140526
#
#
# At random state 67, the training accuracy is: 0.8022719204827831
# At random state 67, the testing accuracy is: 0.815471965933286
#
#
# At random state 68, the training accuracy is: 0.8031593894213702
# At random state 68, the testing accuracy is: 0.808374733853797
#
#
# At random state 69, the training accuracy is: 0.8033368832090877
# At random state 69, the testing accuracy is: 0.808374733853797
#
#
# At random state 70, the training accuracy is: 0.8079517216897408
# At random state 70, the testing accuracy is: 0.794180269694819
#
#
# At random state 71, the training accuracy is: 0.80386936457224
# At random state 71, the testing accuracy is: 0.7977288857345636
#
#
# At random state 72, the training accuracy is: 0.807596734114306
# At random state 72, the testing accuracy is: 0.7991483321504613
#
#
# At random state 73, the training accuracy is: 0.8019169329073482
# At random state 73, the testing accuracy is: 0.8168914123491838
#
#
# At random state 74, the training accuracy is: 0.8072417465388712
# At random state 74, the testing accuracy is: 0.7970191625266146
#
#
# At random state 75, the training accuracy is: 0.8067092651757188
# At random state 75, the testing accuracy is: 0.7984386089425124
#
#
# At random state 76, the training accuracy is: 0.8008519701810437
# At random state 76, the testing accuracy is: 0.8211497515968772
#
#
# At random state 77, the training accuracy is: 0.805111821086262
# At random state 77, the testing accuracy is: 0.7970191625266146
#
#
# At random state 78, the training accuracy is: 0.8068867589634363
# At random state 78, the testing accuracy is: 0.7913413768630234
#
#
# At random state 79, the training accuracy is: 0.8090166844160455
# At random state 79, the testing accuracy is: 0.7899219304471257
#
#
# At random state 80, the training accuracy is: 0.8019169329073482
# At random state 80, the testing accuracy is: 0.8140525195173882
#
#
# At random state 81, the training accuracy is: 0.811324103656372
# At random state 81, the testing accuracy is: 0.78708303761533
#
#
# At random state 82, the training accuracy is: 0.8067092651757188
# At random state 82, the testing accuracy is: 0.8019872249822569
#
#
# At random state 83, the training accuracy is: 0.8070642527511537
# At random state 83, the testing accuracy is: 0.7955997161107168
#
#
# At random state 84, the training accuracy is: 0.8102591409300675
# At random state 84, the testing accuracy is: 0.7828246983676366
#
#
# At random state 85, the training accuracy is: 0.8061767838125665
# At random state 85, the testing accuracy is: 0.794889992902768
#
#
# At random state 86, the training accuracy is: 0.8074192403265885
# At random state 86, the testing accuracy is: 0.794889992902768
#
#
# At random state 87, the training accuracy is: 0.811324103656372
# At random state 87, the testing accuracy is: 0.7885024840312278
#
#
# At random state 88, the training accuracy is: 0.805111821086262
# At random state 88, the testing accuracy is: 0.8026969481902059
#
#
# At random state 89, the training accuracy is: 0.8029818956336529
# At random state 89, the testing accuracy is: 0.8161816891412349
#
#
# At random state 90, the training accuracy is: 0.80386936457224
# At random state 90, the testing accuracy is: 0.7991483321504613
#
#
# At random state 91, the training accuracy is: 0.8070642527511537
# At random state 91, the testing accuracy is: 0.8041163946061036
#
#
# At random state 92, the training accuracy is: 0.8017394391196309
# At random state 92, the testing accuracy is: 0.8261178140525195
#
#
# At random state 93, the training accuracy is: 0.8084842030528931
# At random state 93, the testing accuracy is: 0.7806955287437899
#
#
# At random state 94, the training accuracy is: 0.8065317713880015
# At random state 94, the testing accuracy is: 0.8005677785663591
#
#
# At random state 95, the training accuracy is: 0.8104366347177849
# At random state 95, the testing accuracy is: 0.7842441447835344
#
#
# At random state 96, the training accuracy is: 0.8079517216897408
# At random state 96, the testing accuracy is: 0.7899219304471257
#
#
# At random state 97, the training accuracy is: 0.8033368832090877
# At random state 97, the testing accuracy is: 0.8005677785663591
#
#
# At random state 98, the training accuracy is: 0.8033368832090877
# At random state 98, the testing accuracy is: 0.808374733853797
#
#
# At random state 99, the training accuracy is: 0.806354277600284
# At random state 99, the testing accuracy is: 0.8041163946061036
#
#
# At random state 100, the training accuracy is: 0.8070642527511537
# At random state 100, the testing accuracy is: 0.7877927608232789
#
#
# At random state 101, the training accuracy is: 0.806354277600284
# At random state 101, the testing accuracy is: 0.7984386089425124
#
#
# At random state 102, the training accuracy is: 0.8054668086616968
# At random state 102, the testing accuracy is: 0.801277501774308
#
#
# At random state 103, the training accuracy is: 0.805111821086262
# At random state 103, the testing accuracy is: 0.801277501774308
#
#
# At random state 104, the training accuracy is: 0.8008519701810437
# At random state 104, the testing accuracy is: 0.8161816891412349
#
#
# At random state 105, the training accuracy is: 0.8045793397231097
# At random state 105, the testing accuracy is: 0.8041163946061036
#
#
# At random state 106, the training accuracy is: 0.8012069577564785
# At random state 106, the testing accuracy is: 0.8097941802696949
#
#
# At random state 107, the training accuracy is: 0.8065317713880015
# At random state 107, the testing accuracy is: 0.8097941802696949
#
#
# At random state 108, the training accuracy is: 0.8097266595669151
# At random state 108, the testing accuracy is: 0.7877927608232789
#
#
# At random state 109, the training accuracy is: 0.8067092651757188
# At random state 109, the testing accuracy is: 0.7963094393186657
#
#
# At random state 110, the training accuracy is: 0.8079517216897408
# At random state 110, the testing accuracy is: 0.7913413768630234
#
#
# At random state 111, the training accuracy is: 0.8017394391196309
# At random state 111, the testing accuracy is: 0.8055358410220014
#
#
# At random state 112, the training accuracy is: 0.8072417465388712
# At random state 112, the testing accuracy is: 0.794889992902768
#
#
# At random state 113, the training accuracy is: 0.8036918707845225
# At random state 113, the testing accuracy is: 0.7934705464868701
#
#
# At random state 114, the training accuracy is: 0.808839190628328
# At random state 114, the testing accuracy is: 0.7934705464868701
#
#
# At random state 115, the training accuracy is: 0.8036918707845225
# At random state 115, the testing accuracy is: 0.8112136266855926
#
#
# At random state 116, the training accuracy is: 0.8067092651757188
# At random state 116, the testing accuracy is: 0.7998580553584103
#
#
# At random state 117, the training accuracy is: 0.8059992900248492
# At random state 117, the testing accuracy is: 0.7977288857345636
#
#
# At random state 118, the training accuracy is: 0.807596734114306
# At random state 118, the testing accuracy is: 0.7934705464868701
#
#
# At random state 119, the training accuracy is: 0.8049343272985445
# At random state 119, the testing accuracy is: 0.8026969481902059
#
#
# At random state 120, the training accuracy is: 0.8054668086616968
# At random state 120, the testing accuracy is: 0.8048261178140526
#
#
# At random state 121, the training accuracy is: 0.806354277600284
# At random state 121, the testing accuracy is: 0.794889992902768
#
#
# At random state 122, the training accuracy is: 0.8045793397231097
# At random state 122, the testing accuracy is: 0.8048261178140526
#
#
# At random state 123, the training accuracy is: 0.8035143769968051
# At random state 123, the testing accuracy is: 0.8041163946061036
#
#
# At random state 124, the training accuracy is: 0.8004969826056088
# At random state 124, the testing accuracy is: 0.8190205819730305
#
#
# At random state 125, the training accuracy is: 0.8036918707845225
# At random state 125, the testing accuracy is: 0.8069552874378992
#
#
# At random state 126, the training accuracy is: 0.80386936457224
# At random state 126, the testing accuracy is: 0.8161816891412349
#
#
# At random state 127, the training accuracy is: 0.8054668086616968
# At random state 127, the testing accuracy is: 0.8055358410220014
# At random state 128, the training accuracy is: 0.8056443024494143
# At random state 128, the testing accuracy is: 0.8133427963094393
#
#
# At random state 129, the training accuracy is: 0.8017394391196309
# At random state 129, the testing accuracy is: 0.8176011355571328
#
#
# At random state 130, the training accuracy is: 0.81008164714235
# At random state 130, the testing accuracy is: 0.7920511000709723
#
#
# At random state 131, the training accuracy is: 0.8070642527511537
# At random state 131, the testing accuracy is: 0.7991483321504613
#
#
# At random state 132, the training accuracy is: 0.8035143769968051
# At random state 132, the testing accuracy is: 0.8055358410220014
#
#
# At random state 133, the training accuracy is: 0.8054668086616968
# At random state 133, the testing accuracy is: 0.7963094393186657
#
#
# At random state 134, the training accuracy is: 0.8083067092651757
# At random state 134, the testing accuracy is: 0.7963094393186657
#
#
# At random state 135, the training accuracy is: 0.8067092651757188
# At random state 135, the testing accuracy is: 0.8048261178140526
#
#
# At random state 136, the training accuracy is: 0.8059992900248492
# At random state 136, the testing accuracy is: 0.8019872249822569
#
#
# At random state 137, the training accuracy is: 0.805111821086262
# At random state 137, the testing accuracy is: 0.8026969481902059
#
#
# At random state 138, the training accuracy is: 0.806354277600284
# At random state 138, the testing accuracy is: 0.7885024840312278
#
#
# At random state 139, the training accuracy is: 0.7992545260915868
# At random state 139, the testing accuracy is: 0.8239886444286728
#
#
# At random state 140, the training accuracy is: 0.8031593894213702
# At random state 140, the testing accuracy is: 0.8112136266855926
#
#
# At random state 141, the training accuracy is: 0.8040468583599574
# At random state 141, the testing accuracy is: 0.7963094393186657
#
#
# At random state 142, the training accuracy is: 0.8065317713880015
# At random state 142, the testing accuracy is: 0.794889992902768
#
#
# At random state 143, the training accuracy is: 0.8056443024494143
# At random state 143, the testing accuracy is: 0.7977288857345636
#
#
# At random state 144, the training accuracy is: 0.8081292154774583
# At random state 144, the testing accuracy is: 0.794180269694819
#
#
# At random state 145, the training accuracy is: 0.8022719204827831
# At random state 145, the testing accuracy is: 0.8168914123491838
#
#
# At random state 146, the training accuracy is: 0.8042243521476748
# At random state 146, the testing accuracy is: 0.7991483321504613
#
#
# At random state 147, the training accuracy is: 0.8022719204827831
# At random state 147, the testing accuracy is: 0.8105039034776437
#
#
# At random state 148, the training accuracy is: 0.8070642527511537
# At random state 148, the testing accuracy is: 0.7970191625266146
#
#
# At random state 149, the training accuracy is: 0.8031593894213702
# At random state 149, the testing accuracy is: 0.7991483321504613
#
#
# At random state 150, the training accuracy is: 0.7981895633652822
# At random state 150, the testing accuracy is: 0.8239886444286728
#
#
# At random state 151, the training accuracy is: 0.8106141285055023
# At random state 151, the testing accuracy is: 0.7856635911994322
#
#
# At random state 152, the training accuracy is: 0.8070642527511537
# At random state 152, the testing accuracy is: 0.7970191625266146
#
#
# At random state 153, the training accuracy is: 0.808839190628328
# At random state 153, the testing accuracy is: 0.7849538679914834
#
#
# At random state 154, the training accuracy is: 0.8040468583599574
# At random state 154, the testing accuracy is: 0.8019872249822569
#
#
# At random state 155, the training accuracy is: 0.8079517216897408
# At random state 155, the testing accuracy is: 0.794180269694819
#
#
# At random state 156, the training accuracy is: 0.8024494142705005
# At random state 156, the testing accuracy is: 0.808374733853797
#
#
# At random state 157, the training accuracy is: 0.8045793397231097
# At random state 157, the testing accuracy is: 0.8055358410220014
#
#
# At random state 158, the training accuracy is: 0.8017394391196309
# At random state 158, the testing accuracy is: 0.8254080908445706
#
#
# At random state 159, the training accuracy is: 0.8003194888178914
# At random state 159, the testing accuracy is: 0.8126330731014905
#
#
# At random state 160, the training accuracy is: 0.8083067092651757
# At random state 160, the testing accuracy is: 0.7934705464868701
#
#
# At random state 161, the training accuracy is: 0.8042243521476748
# At random state 161, the testing accuracy is: 0.8112136266855926
#
#
# At random state 162, the training accuracy is: 0.8056443024494143
# At random state 162, the testing accuracy is: 0.8062455642299503
#
#
# At random state 163, the training accuracy is: 0.805111821086262
# At random state 163, the testing accuracy is: 0.794889992902768
#
#
# At random state 164, the training accuracy is: 0.8047568335108272
# At random state 164, the testing accuracy is: 0.794180269694819
#
#
# At random state 165, the training accuracy is: 0.8065317713880015
# At random state 165, the testing accuracy is: 0.794889992902768
#
#
# At random state 166, the training accuracy is: 0.802626908058218
# At random state 166, the testing accuracy is: 0.8062455642299503
#
#
# At random state 167, the training accuracy is: 0.8029818956336529
# At random state 167, the testing accuracy is: 0.7998580553584103
#
#
# At random state 168, the training accuracy is: 0.8070642527511537
# At random state 168, the testing accuracy is: 0.794889992902768
#
#
# At random state 169, the training accuracy is: 0.8079517216897408
# At random state 169, the testing accuracy is: 0.7977288857345636
#
#
# At random state 170, the training accuracy is: 0.805111821086262
# At random state 170, the testing accuracy is: 0.8055358410220014
#
#
# At random state 171, the training accuracy is: 0.8015619453319134
# At random state 171, the testing accuracy is: 0.8126330731014905
#
#
# At random state 172, the training accuracy is: 0.8045793397231097
# At random state 172, the testing accuracy is: 0.8055358410220014
#
#
# At random state 173, the training accuracy is: 0.805111821086262
# At random state 173, the testing accuracy is: 0.8076650106458482
#
#
# At random state 174, the training accuracy is: 0.8010294639687611
# At random state 174, the testing accuracy is: 0.8197303051809794
#
#
# At random state 175, the training accuracy is: 0.8052893148739794
# At random state 175, the testing accuracy is: 0.794180269694819
#
#
# At random state 176, the training accuracy is: 0.8058217962371317
# At random state 176, the testing accuracy is: 0.7955997161107168
#
#
# At random state 177, the training accuracy is: 0.8015619453319134
# At random state 177, the testing accuracy is: 0.8097941802696949
#
#
# At random state 178, the training accuracy is: 0.8033368832090877
# At random state 178, the testing accuracy is: 0.8105039034776437
#
#
# At random state 179, the training accuracy is: 0.8029818956336529
# At random state 179, the testing accuracy is: 0.8034066713981547
#
#
# At random state 180, the training accuracy is: 0.8079517216897408
# At random state 180, the testing accuracy is: 0.7927608232789212
#
#
# At random state 181, the training accuracy is: 0.80386936457224
# At random state 181, the testing accuracy is: 0.8090844570617459
#
#
# At random state 182, the training accuracy is: 0.8028044018459354
# At random state 182, the testing accuracy is: 0.8090844570617459
#
#
# At random state 183, the training accuracy is: 0.80386936457224
# At random state 183, the testing accuracy is: 0.808374733853797
#
#
# At random state 184, the training accuracy is: 0.8033368832090877
# At random state 184, the testing accuracy is: 0.8062455642299503
#
#
# At random state 185, the training accuracy is: 0.811324103656372
# At random state 185, the testing accuracy is: 0.7806955287437899
#
#
# At random state 186, the training accuracy is: 0.8072417465388712
# At random state 186, the testing accuracy is: 0.7955997161107168
#
#
# At random state 187, the training accuracy is: 0.806354277600284
# At random state 187, the testing accuracy is: 0.8005677785663591
#
#
# At random state 188, the training accuracy is: 0.8074192403265885
# At random state 188, the testing accuracy is: 0.7920511000709723
#
#
# At random state 189, the training accuracy is: 0.8091941782037628
# At random state 189, the testing accuracy is: 0.7892122072391767
#
#
# At random state 190, the training accuracy is: 0.8045793397231097
# At random state 190, the testing accuracy is: 0.8026969481902059
#
#
# At random state 191, the training accuracy is: 0.8047568335108272
# At random state 191, the testing accuracy is: 0.7991483321504613
# At random state 192, the training accuracy is: 0.8061767838125665
# At random state 192, the testing accuracy is: 0.8062455642299503
#
#
# At random state 193, the training accuracy is: 0.8024494142705005
# At random state 193, the testing accuracy is: 0.8055358410220014
#
#
# At random state 194, the training accuracy is: 0.8054668086616968
# At random state 194, the testing accuracy is: 0.8041163946061036
#
#
# At random state 195, the training accuracy is: 0.8047568335108272
# At random state 195, the testing accuracy is: 0.8019872249822569
#
#
# At random state 196, the training accuracy is: 0.8079517216897408
# At random state 196, the testing accuracy is: 0.7885024840312278
#
#
# At random state 197, the training accuracy is: 0.8056443024494143
# At random state 197, the testing accuracy is: 0.8019872249822569
#
#
# At random state 198, the training accuracy is: 0.8028044018459354
# At random state 198, the testing accuracy is: 0.8133427963094393
#
#
# At random state 199, the training accuracy is: 0.8068867589634363
# At random state 199, the testing accuracy is: 0.7899219304471257

# %% [markdown]
# We are getting best testing accuracy as 82.61% and training accuracy as 80.17% on random state 92. Hence, we select random state as 92.

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.22,random_state=92)

# %% [markdown]
# We split our data into Training and Testing giving 78% data for Training and 22% for Testing at best random state 92. We will use different algorithms for comparing accuracies and attain the best model. We will compare Logitic Regression, GaussianNB, SVC and KNeighborsClassifier in this case.

# %%
model=[LogisticRegression(),GaussianNB(),KNeighborsClassifier(),SVC()]

# %%
for m in model:
    m.fit(x_train,y_train)
    m.score(x_train,y_train)
    predm=m.predict(x_test)
    print('Accuracy score of',m,'is:')
    print(accuracy_score(y_test,predm))
    print(confusion_matrix(y_test,predm))
    print(classification_report(y_test,predm))
    print('\n')
# Out:
# Accuracy score of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False) is:
# 0.82
# [[1046   94]
#  [ 185  225]]
#               precision    recall  f1-score   support
#
#          0.0       0.85      0.92      0.88      1140
#          1.0       0.71      0.55      0.62       410
#
#    micro avg       0.82      0.82      0.82      1550
#    macro avg       0.78      0.73      0.75      1550
# weighted avg       0.81      0.82      0.81      1550
#
#
#
# Accuracy score of GaussianNB(priors=None, var_smoothing=1e-09) is:
# 0.7664516129032258
# [[890 250]
#  [112 298]]
#               precision    recall  f1-score   support
#
#          0.0       0.89      0.78      0.83      1140
#          1.0       0.54      0.73      0.62       410
#
#    micro avg       0.77      0.77      0.77      1550
#    macro avg       0.72      0.75      0.73      1550
# weighted avg       0.80      0.77      0.78      1550
#
#
#
# Accuracy score of KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform') is:
# 0.747741935483871
# [[990 150]
#  [241 169]]
#               precision    recall  f1-score   support
#
#          0.0       0.80      0.87      0.84      1140
#          1.0       0.53      0.41      0.46       410
#
#    micro avg       0.75      0.75      0.75      1550
#    macro avg       0.67      0.64      0.65      1550
# weighted avg       0.73      0.75      0.74      1550
#
#
#
# Accuracy score of SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False) is:
# 0.7561290322580645
# [[1113   27]
#  [ 351   59]]
#               precision    recall  f1-score   support
#
#          0.0       0.76      0.98      0.85      1140
#          1.0       0.69      0.14      0.24       410
#
#    micro avg       0.76      0.76      0.76      1550
#    macro avg       0.72      0.56      0.55      1550
# weighted avg       0.74      0.76      0.69      1550

# %% [markdown]
# We get accuracy 82% for Logistic Regression, 76.64% for GaussianNB, 74.77% for KNeighborsClassifier and 75.61% for SVC.

# %% [markdown]
# We might attain this accuracy due to Overfitting/Underfitting problems as well. Let's use different Testing Techniques to test accuracy.

# %% [markdown]
# # Cross Validation of the Model

# %%
#Finding best cv score at a particular cv
pred_train=lr.predict(x_train)
pred_test=lr.predict(x_test)
train_accuracy=accuracy_score(y_train,pred_train)
test_accuracy=accuracy_score(y_test,pred_test)

from sklearn.model_selection import cross_val_score
for j in range(2,10):
    cv_score=cross_val_score(lr,x,y,cv=j)
    cv_mean=cv_score.mean()
    print(f"At cross fold {j} the cv score is {cv_mean} and r2 score for training is {train_accuracy} and accuracy for the testing is {test_accuracy}")
    print("\n")
# Out:
# At cross fold 2 the cv score is 0.7993750001007986 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 3 the cv score is 0.8053393521082528 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 4 the cv score is 0.8026409977115996 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 5 the cv score is 0.8023589847578492 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 6 the cv score is 0.8034943679805502 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 7 the cv score is 0.8047718794341343 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 8 the cv score is 0.8029317243847398 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258
#
#
# At cross fold 9 the cv score is 0.8034963321027138 and r2 score for training is 0.7970143819406518 and accuracy for the testing is 0.8264516129032258

# %% [markdown]
# cv=3 gives us the best cv score at 80.53% for Logistic Regression. We use cv=3 for cross validation. We will check cross validation on all the algorithms that we've used above.

# %%
for m in model:
    cv_score=cross_val_score(m,x,y,cv=j)
    cv_mean=cv_score.mean()
    print("Cross Validation score of ",m," model: ",cv_score.mean())
    print('\n')
    print('\n')
# Out:
# Cross Validation score of  LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)  model:  0.8034963321027138
#
#
#
#
# Cross Validation score of  GaussianNB(priors=None, var_smoothing=1e-09)  model:  0.7557872336756024
#
#
#
#
# Cross Validation score of  KNeighborsClassifier(algorithm='auto', leaf_size=30, metric='minkowski',
#            metric_params=None, n_jobs=None, n_neighbors=5, p=2,
#            weights='uniform')  model:  0.7513843874297312
#
#
#
#
# Cross Validation score of  SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False)  model:  0.7579181612992517

# %% [markdown]
# The cross Validation score for Logistic Regression is 80.34%, GaussianNB is 75.57, KNeighborsClassifier is 75.13 and SVC is 75.79.

# %% [markdown]
# The difference between the accuracy score and cv score of Logistic Regression is 1.66, GaussianNB is 1.07, KNeighborsClassifier is 0.36 and SVC is 0.18.

# %% [markdown]
# Hence, SVC is giving us better accuracy than that of any other algorithm used. So we proceed using SVC for our project.

# %% [markdown]
# # Ensemble Techniques

# %%
#importing libraries
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
svc=SVC()

# %%
#Create adaboost classifier object
ad=AdaBoostClassifier(n_estimators=50, base_estimator=svc,algorithm='SAMME')
ad.fit(x_train,y_train)
# Out:
# AdaBoostClassifier(algorithm='SAMME',
#           base_estimator=SVC(C=1.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma='auto_deprecated',
#   kernel='rbf', max_iter=-1, probability=False, random_state=None,
#   shrinking=True, tol=0.001, verbose=False),
#           learning_rate=1.0, n_estimators=50, random_state=None)

# %%
#printing accuracy metrics
ad_pred=ad.predict(x_test)
print(accuracy_score(y_test,ad_pred))
print(confusion_matrix(y_test,ad_pred))
print(classification_report(y_test,ad_pred))
# Out:
# 0.7354838709677419
# [[1140    0]
#  [ 410    0]]
#               precision    recall  f1-score   support
#
#          0.0       0.74      1.00      0.85      1140
#          1.0       0.00      0.00      0.00       410
#
#    micro avg       0.74      0.74      0.74      1550
#    macro avg       0.37      0.50      0.42      1550
# weighted avg       0.54      0.74      0.62      1550

# %% [markdown]
# We get an accuracy score of 73.54% by using Ensemble Technique Ada Boost Classifier keeping it's base estimator as SVC because SVC gave us the best accuracy for it's cross validation. Hence, we continued to use this algorithm and apply different testing techniques to it to attain the best accuracy.

# %% [markdown]
# # Creating Confusion Matrix

# %%
#Importing Libraries to create confusion matrix
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import cross_val_predict
from sklearn.metrics import confusion_matrix

import warnings
warnings.filterwarnings('ignore')

# %%
#Creating confusion matrix
svc=SVC()

score=cross_val_score(svc,x,y,cv=3)
print("Score:",score)

print("Mean Scores",score.mean())
print("Standard deviation",score.std())

y_pred=cross_val_predict(svc,x,y,cv=3)

print('Y Prediction values ')
print(y_pred)
conf_mat=confusion_matrix(y,y_pred)
conf_mat
# Out:
# Score: [0.75596252 0.75383305 0.75713677]
# Mean Scores 0.7556441136811961
# Standard deviation 0.00136740156766511
# Y Prediction values
# [0. 0. 0. ... 0. 0. 0.]
# array([[5084,   90],
#        [1631,  238]], dtype=int64)

# %% [markdown]
# After applying confusion matrix to our algorithm, we get our cross val mean score as 75.56% with standard deviation of 0.001 which is very less which indicates that the data points tend to be very close to the mean.

# %% [markdown]
# From the above confusion matrix, we can observe that True Positive is 5084 and True Negative is 238, rest all are Type 1 and Type 2 errors.

# %% [markdown]
# # Saving The Model

# %%
import pickle
filename='Customer_Churn.pkl'
pickle.dump(ad,open(filename,'wb'))
